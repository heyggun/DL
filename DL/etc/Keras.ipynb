# %% [markdown]
# # Keras
#
# ( https://keras.io/ or https://www.tensorflow.org/guide/keras?hl=ko )

# %% [markdown]
# ### Preprocessing

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# `Tokenizer()` : 토큰화와 정수 인코딩을 위해 사용함
#
#     - 훈련 데이터로부터 단어 집합을 생성하고, 해당 단어 집합으로 임의의 문장을 정수 인코딩함

# %%
tokenizer = Tokenizer()
train_text = 'The earth is an awesome place live'

# 단어 집합 생성
tokenizer.fit_on_texts([train_text])

#정수 인코딩
sub_text = 'The earth is an great place live'
sequences = tokenizer.texts_to_sequences([sub_text])[0]

# %%
print(f" 정수 인코딩 : {sequences}")
print(f" 단어 집합 : {tokenizer.word_index}")
# Out:
#  정수 인코딩 : [1, 2, 3, 4, 6, 7]
#  단어 집합 : {'the': 1, 'earth': 2, 'is': 3, 'an': 4, 'awesome': 5, 'place': 6, 'live': 7}

# %% [markdown]
#     ->  'greate'는 단어 집합(vocabulary)에 없어서 출력되지 않음

# %% [markdown]
# `pad_sequences(패딩을 진행할 데이터, maxlen='정규화할 길이', padding='pre'면 앞에, 'post'면 뒤에 0을 채움)`
#
#     - 전체 훈련 데이터에서 각 샘플의 데이터가 서로 다를 수 있음
#     - 모델의 입력으로 사용하려면 모든 샘플의 길이를 동일하게 만들어야 하는데, 자연어 처리의 패딩(padding) 작업
#     - 숫자 0을 넣어서 길이가 다른 샘플들의 길이를 맞춰줌
#     - 정해진 길이보다 길이가 길면 일부자르고, 정해준 길이보다 짧으면 0으로 채움

# %%
pad_sequences([[1,2,3], [3,4,5,6], [7,8]], maxlen=3, padding='pre')
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [0, 7, 8]])

# %% [markdown]
# ## word embedding
#
#     - embedding : 텍스트 내의 단어들을 밀집벡터(dense vector)로 만드는 것
#                 : 상대적으로 저차원을 가지며 모든 원소의 값이 실수임
#     - one-hot vector : 대부분 0의 값, 하나의 1의 값을 가지는 벡터 (차원이 대체적으로 큼)
#                      : one-hot vector는 단어 집합의 크기만큼 벡터의 차원을 가지고, 단어 벡터 간의 유의미한 유사도 구할 수 없음

# %% [markdown]
# `embedding(단어집합의크기[총 단어 개수], 임베딩 벡터의 출력 차원, 입력 시퀀스의 길이)`
#
#     - 단어를 밀집 벡터로 만듦.
#     - 임베딩 층(embedding layer)를 만드는 역할을 함
#     - 정수 인코딩이 된 단어들을 입력받아서 임베딩을 수행함

# %% [markdown]
# ## 모델링(Modeling)

# %% [markdown]
# `Sequential()`
#
#     - 인공신경망의 층 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(1, input_dim=3, activation='relu'))

# %%
model = Sequential()
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 8)                 40
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일(complie)과 훈련(Training)

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.models import Sequential

vocab_size=1000
embedding_dim=32
hidden_units=32

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(SimpleRNN(hidden_units))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])

# %% [markdown]
# # Functional API (함수형 API)

# %% [markdown]
# `Sequential API`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(3, input_dim=4, activation='softmax'))

# %% [markdown]
# `Functional API`
#
#
#     - 입력 데이터 크기(shape)를 인자로 입력층을 정의해 주어야 함

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# %%
inputs = Input(shape=(10,))
hidden1 = Dense(64, activation='relu')(inputs)
hidden2 = Dense(64, activation='relu')(hidden1)
output = Dense(1, activation='sigmoid')(hidden2)

model = Model(inputs=inputs, outputs=output)

# %% [markdown]
#     - input() 함수에 입력의 크기 정의
#     - 이전층을 다음층 함수의 입력으로 사용하고, 변수에 할당
#     - Model() 함수에 입력과 출력 정의

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# FFNN

# %%
inputs = Input(shape=(10,))
x = Dense(8, activation='relu')(inputs)
x = Dense(4, activation='relu')(x)
x = Dense(1, activation='linear')(x)
model = Model(inputs, x)

# %% [markdown]
# # Linear Regression - Functional API

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers

# %%
X = [1,2,3,4,5,6,7,8,9]
y = [11,22,33,44,54,66,77,87,95]

inputs = Input(shape=(1,))
output = Dense(1, activation='linear')(inputs)
linear_model = Model(inputs, output)

sgd = optimizers.SGD(lr=0.01)

linear_model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
linear_model.fit(X, y, epochs=300)
# Out:
# Epoch 1/300
# C:\Users\PC\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 0s 253ms/step - loss: 3446.7480 - mse: 3446.7480
# Epoch 2/300
# 1/1 [==============================] - 0s 4ms/step - loss: 424.9640 - mse: 424.9640
# Epoch 3/300
# 1/1 [==============================] - 0s 4ms/step - loss: 53.1555 - mse: 53.1555
# Epoch 4/300
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4066 - mse: 7.4066
# Epoch 5/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7768 - mse: 1.7768
# Epoch 6/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0833 - mse: 1.0833
# Epoch 7/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9973 - mse: 0.9973
# Epoch 8/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9860 - mse: 0.9860
# Epoch 9/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9839 - mse: 0.9839
# Epoch 10/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9830 - mse: 0.9830
# Epoch 11/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9822 - mse: 0.9822
# Epoch 12/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9814 - mse: 0.9814
# Epoch 13/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9806 - mse: 0.9806
# Epoch 14/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9799 - mse: 0.9799
# Epoch 15/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9791 - mse: 0.9791
# Epoch 16/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9783 - mse: 0.9783
# Epoch 17/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9776 - mse: 0.9776
# Epoch 18/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9768 - mse: 0.9768
# Epoch 19/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9761 - mse: 0.9761
# Epoch 20/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9754 - mse: 0.9754
# Epoch 21/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9747 - mse: 0.9747
# Epoch 22/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9739 - mse: 0.9739
# Epoch 23/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9732 - mse: 0.9732
# Epoch 24/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9725 - mse: 0.9725
# Epoch 25/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9718 - mse: 0.9718
# Epoch 26/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9711 - mse: 0.9711
# Epoch 27/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9704 - mse: 0.9704
# Epoch 28/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9698 - mse: 0.9698
# Epoch 29/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9691 - mse: 0.9691
# Epoch 30/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9684 - mse: 0.9684
# Epoch 31/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9677 - mse: 0.9677
# Epoch 32/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9671 - mse: 0.9671
# Epoch 33/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9664 - mse: 0.9664
# Epoch 34/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9658 - mse: 0.9658
# Epoch 35/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9651 - mse: 0.9651
# Epoch 36/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9645 - mse: 0.9645
# Epoch 37/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9638 - mse: 0.9638
# Epoch 38/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9632 - mse: 0.9632
# Epoch 39/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9626 - mse: 0.9626
# Epoch 40/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9620 - mse: 0.9620
# Epoch 41/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9614 - mse: 0.9614
# Epoch 42/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9607 - mse: 0.9607
# Epoch 43/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9601 - mse: 0.9601
# Epoch 44/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9595 - mse: 0.9595
# Epoch 45/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9589 - mse: 0.9589
# Epoch 46/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9584 - mse: 0.9584
# Epoch 47/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9578 - mse: 0.9578
# Epoch 48/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9572 - mse: 0.9572
# Epoch 49/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9566 - mse: 0.9566
# Epoch 50/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9560 - mse: 0.9560
# Epoch 51/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9555 - mse: 0.9555
# Epoch 52/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9549 - mse: 0.9549
# Epoch 53/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9544 - mse: 0.9544
# Epoch 54/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9538 - mse: 0.9538
# Epoch 55/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9533 - mse: 0.9533
# Epoch 56/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9527 - mse: 0.9527
# Epoch 57/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9522 - mse: 0.9522
# Epoch 58/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9516 - mse: 0.9516
# Epoch 59/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9511 - mse: 0.9511
# Epoch 60/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9506 - mse: 0.9506
# Epoch 61/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9501 - mse: 0.9501
# Epoch 62/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9496 - mse: 0.9496
# Epoch 63/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9490 - mse: 0.9490
# Epoch 64/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9485 - mse: 0.9485
# Epoch 65/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9480 - mse: 0.9480
# Epoch 66/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9475 - mse: 0.9475
# Epoch 67/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9470 - mse: 0.9470
# Epoch 68/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9465 - mse: 0.9465
# Epoch 69/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9461 - mse: 0.9461
# Epoch 70/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9456 - mse: 0.9456
# Epoch 71/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9451 - mse: 0.9451
# Epoch 72/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9446 - mse: 0.9446
# Epoch 73/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9441 - mse: 0.9441
# Epoch 74/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9437 - mse: 0.9437
# Epoch 75/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9432 - mse: 0.9432
# Epoch 76/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9428 - mse: 0.9428
# Epoch 77/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9423 - mse: 0.9423
# Epoch 78/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9418 - mse: 0.9418
# Epoch 79/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9414 - mse: 0.9414
# Epoch 80/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9410 - mse: 0.9410
# Epoch 81/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9405 - mse: 0.9405
# Epoch 82/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9401 - mse: 0.9401
# Epoch 83/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9396 - mse: 0.9396
# Epoch 84/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9392 - mse: 0.9392
# Epoch 85/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9388 - mse: 0.9388
# Epoch 86/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9384 - mse: 0.9384
# Epoch 87/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9379 - mse: 0.9379
# Epoch 88/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9375 - mse: 0.9375
# Epoch 89/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9371 - mse: 0.9371
# Epoch 90/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9367 - mse: 0.9367
# Epoch 91/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9363 - mse: 0.9363
# Epoch 92/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9359 - mse: 0.9359
# Epoch 93/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9355 - mse: 0.9355
# Epoch 94/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9351 - mse: 0.9351
# Epoch 95/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9347 - mse: 0.9347
# Epoch 96/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9343 - mse: 0.9343
# Epoch 97/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9339 - mse: 0.9339
# Epoch 98/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9335 - mse: 0.9335
# Epoch 99/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9331 - mse: 0.9331
# Epoch 100/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9328 - mse: 0.9328
# Epoch 101/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9324 - mse: 0.9324
# Epoch 102/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9320 - mse: 0.9320
# Epoch 103/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9317 - mse: 0.9317
# Epoch 104/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9313 - mse: 0.9313
# Epoch 105/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9309 - mse: 0.9309
# Epoch 106/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9306 - mse: 0.9306
# Epoch 107/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9302 - mse: 0.9302
# Epoch 108/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9299 - mse: 0.9299
# Epoch 109/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9295 - mse: 0.9295
# Epoch 110/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9292 - mse: 0.9292
# Epoch 111/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9288 - mse: 0.9288
# Epoch 112/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9285 - mse: 0.9285
# Epoch 113/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9281 - mse: 0.9281
# Epoch 114/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9278 - mse: 0.9278
# Epoch 115/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9275 - mse: 0.9275
# Epoch 116/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9271 - mse: 0.9271
# Epoch 117/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9268 - mse: 0.9268
# Epoch 118/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9265 - mse: 0.9265
# Epoch 119/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9261 - mse: 0.9261
# Epoch 120/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9258 - mse: 0.9258
# Epoch 121/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9255 - mse: 0.9255
# Epoch 122/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9252 - mse: 0.9252
# Epoch 123/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9249 - mse: 0.9249
# Epoch 124/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9246 - mse: 0.9246
# Epoch 125/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9243 - mse: 0.9243
# Epoch 126/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9240 - mse: 0.9240
# Epoch 127/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9237 - mse: 0.9237
# Epoch 128/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9234 - mse: 0.9234
# Epoch 129/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9231 - mse: 0.9231
# Epoch 130/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9228 - mse: 0.9228
# Epoch 131/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9225 - mse: 0.9225
# Epoch 132/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9222 - mse: 0.9222
# Epoch 133/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9219 - mse: 0.9219
# Epoch 134/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9216 - mse: 0.9216
# Epoch 135/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9213 - mse: 0.9213
# Epoch 136/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9210 - mse: 0.9210
# Epoch 137/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9208 - mse: 0.9208
# Epoch 138/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9205 - mse: 0.9205
# Epoch 139/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9202 - mse: 0.9202
# Epoch 140/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9199 - mse: 0.9199
# Epoch 141/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9197 - mse: 0.9197
# Epoch 142/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9194 - mse: 0.9194
# Epoch 143/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9191 - mse: 0.9191
# Epoch 144/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9189 - mse: 0.9189
# Epoch 145/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9186 - mse: 0.9186
# Epoch 146/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9184 - mse: 0.9184
# Epoch 147/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9181 - mse: 0.9181
# Epoch 148/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9178 - mse: 0.9178
# Epoch 149/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9176 - mse: 0.9176
# Epoch 150/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9173 - mse: 0.9173
# Epoch 151/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9171 - mse: 0.9171
# Epoch 152/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9168 - mse: 0.9168
# Epoch 153/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9166 - mse: 0.9166
# Epoch 154/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9164 - mse: 0.9164
# Epoch 155/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9161 - mse: 0.9161
# Epoch 156/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9159 - mse: 0.9159
# Epoch 157/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9156 - mse: 0.9156
# Epoch 158/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9154 - mse: 0.9154
# Epoch 159/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9152 - mse: 0.9152
# Epoch 160/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9149 - mse: 0.9149
# Epoch 161/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9147 - mse: 0.9147
# Epoch 162/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9145 - mse: 0.9145
# Epoch 163/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9143 - mse: 0.9143
# Epoch 164/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9140 - mse: 0.9140
# Epoch 165/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9138 - mse: 0.9138
# Epoch 166/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9136 - mse: 0.9136
# Epoch 167/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9134 - mse: 0.9134
# Epoch 168/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9132 - mse: 0.9132
# Epoch 169/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9129 - mse: 0.9129
# Epoch 170/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9127 - mse: 0.9127
# Epoch 171/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9125 - mse: 0.9125
# Epoch 172/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9123 - mse: 0.9123
# Epoch 173/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9121 - mse: 0.9121
# Epoch 174/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9119 - mse: 0.9119
# Epoch 175/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9117 - mse: 0.9117
# Epoch 176/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9115 - mse: 0.9115
# Epoch 177/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9113 - mse: 0.9113
# Epoch 178/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9111 - mse: 0.9111
# Epoch 179/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9109 - mse: 0.9109
# Epoch 180/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9107 - mse: 0.9107
# Epoch 181/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9105 - mse: 0.9105
# Epoch 182/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9103 - mse: 0.9103
# Epoch 183/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9101 - mse: 0.9101
# Epoch 184/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9099 - mse: 0.9099
# Epoch 185/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9098 - mse: 0.9098
# Epoch 186/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9096 - mse: 0.9096
# Epoch 187/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9094 - mse: 0.9094
# Epoch 188/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9092 - mse: 0.9092
# Epoch 189/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9090 - mse: 0.9090
# Epoch 190/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9088 - mse: 0.9088
# Epoch 191/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9087 - mse: 0.9087
# Epoch 192/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9085 - mse: 0.9085
# Epoch 193/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9083 - mse: 0.9083
# Epoch 194/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9081 - mse: 0.9081
# Epoch 195/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9080 - mse: 0.9080
# Epoch 196/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9078 - mse: 0.9078
# Epoch 197/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9076 - mse: 0.9076
# Epoch 198/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9074 - mse: 0.9074
# Epoch 199/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9073 - mse: 0.9073
# Epoch 200/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9071 - mse: 0.9071
# Epoch 201/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9069 - mse: 0.9069
# Epoch 202/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9068 - mse: 0.9068
# Epoch 203/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9066 - mse: 0.9066
# Epoch 204/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9065 - mse: 0.9065
# Epoch 205/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9063 - mse: 0.9063
# Epoch 206/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9061 - mse: 0.9061
# Epoch 207/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9060 - mse: 0.9060
# Epoch 208/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9058 - mse: 0.9058
# Epoch 209/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9057 - mse: 0.9057
# Epoch 210/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9055 - mse: 0.9055
# Epoch 211/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9054 - mse: 0.9054
# Epoch 212/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9052 - mse: 0.9052
# Epoch 213/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9051 - mse: 0.9051
# Epoch 214/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9049 - mse: 0.9049
# Epoch 215/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9048 - mse: 0.9048
# Epoch 216/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9046 - mse: 0.9046
# Epoch 217/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9045 - mse: 0.9045
# Epoch 218/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9043 - mse: 0.9043
# Epoch 219/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9042 - mse: 0.9042
# Epoch 220/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9041 - mse: 0.9041
# Epoch 221/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9039 - mse: 0.9039
# Epoch 222/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9038 - mse: 0.9038
# Epoch 223/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9037 - mse: 0.9037
# Epoch 224/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9035 - mse: 0.9035
# Epoch 225/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9034 - mse: 0.9034
# Epoch 226/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9032 - mse: 0.9032
# Epoch 227/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9031 - mse: 0.9031
# Epoch 228/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9030 - mse: 0.9030
# Epoch 229/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9029 - mse: 0.9029
# Epoch 230/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9027 - mse: 0.9027
# Epoch 231/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9026 - mse: 0.9026
# Epoch 232/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9025 - mse: 0.9025
# Epoch 233/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9023 - mse: 0.9023
# Epoch 234/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9022 - mse: 0.9022
# Epoch 235/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9021 - mse: 0.9021
# Epoch 236/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9020 - mse: 0.9020
# Epoch 237/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9018 - mse: 0.9018
# Epoch 238/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9017 - mse: 0.9017
# Epoch 239/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9016 - mse: 0.9016
# Epoch 240/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9015 - mse: 0.9015
# Epoch 241/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9014 - mse: 0.9014
# Epoch 242/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9012 - mse: 0.9012
# Epoch 243/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9011 - mse: 0.9011
# Epoch 244/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9010 - mse: 0.9010
# Epoch 245/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9009 - mse: 0.9009
# Epoch 246/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9008 - mse: 0.9008
# Epoch 247/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9007 - mse: 0.9007
# Epoch 248/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9006 - mse: 0.9006
# Epoch 249/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9004 - mse: 0.9004
# Epoch 250/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9003 - mse: 0.9003
# Epoch 251/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9002 - mse: 0.9002
# Epoch 252/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9001 - mse: 0.9001
# Epoch 253/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9000 - mse: 0.9000
# Epoch 254/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8999 - mse: 0.8999
# Epoch 255/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8998 - mse: 0.8998
# Epoch 256/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8997 - mse: 0.8997
# Epoch 257/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8996 - mse: 0.8996
# Epoch 258/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8995 - mse: 0.8995
# Epoch 259/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8994 - mse: 0.8994
# Epoch 260/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8993 - mse: 0.8993
# Epoch 261/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8992 - mse: 0.8992
# Epoch 262/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8991 - mse: 0.8991
# Epoch 263/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8990 - mse: 0.8990
# Epoch 264/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8989 - mse: 0.8989
# Epoch 265/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8988 - mse: 0.8988
# Epoch 266/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8987 - mse: 0.8987
# Epoch 267/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8986 - mse: 0.8986
# Epoch 268/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8985 - mse: 0.8985
# Epoch 269/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8984 - mse: 0.8984
# Epoch 270/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8983 - mse: 0.8983
# Epoch 271/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8982 - mse: 0.8982
# Epoch 272/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8981 - mse: 0.8981
# Epoch 273/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8980 - mse: 0.8980
# Epoch 274/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8980 - mse: 0.8980
# Epoch 275/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8979 - mse: 0.8979
# Epoch 276/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8978 - mse: 0.8978
# Epoch 277/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8977 - mse: 0.8977
# Epoch 278/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8976 - mse: 0.8976
# Epoch 279/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8975 - mse: 0.8975
# Epoch 280/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8974 - mse: 0.8974
# Epoch 281/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8973 - mse: 0.8973
# Epoch 282/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8973 - mse: 0.8973
# Epoch 283/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8972 - mse: 0.8972
# Epoch 284/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8971 - mse: 0.8971
# Epoch 285/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8970 - mse: 0.8970
# Epoch 286/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8969 - mse: 0.8969
# Epoch 287/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8968 - mse: 0.8968
# Epoch 288/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8968 - mse: 0.8968
# Epoch 289/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8967 - mse: 0.8967
# Epoch 290/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8966 - mse: 0.8966
# Epoch 291/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8965 - mse: 0.8965
# Epoch 292/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8964 - mse: 0.8964
# Epoch 293/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8964 - mse: 0.8964
# Epoch 294/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8963 - mse: 0.8963
# Epoch 295/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8962 - mse: 0.8962
# Epoch 296/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8961 - mse: 0.8961
# Epoch 297/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8961 - mse: 0.8961
# Epoch 298/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8960 - mse: 0.8960
# Epoch 299/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8959 - mse: 0.8959
# Epoch 300/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8959 - mse: 0.8959

# %% [markdown]
# # Logistic Regression

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# %%
inputs = Input(shape=(3,))
output = Dense(1, activation='sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# # model that accepts multiple inputs

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate

# %%
inputA = Input(shape=(64,))
inputB = Input(shape=(128,))

x = Dense(16, activation='relu')(inputA)
x = Dense(8, activation='relu')(x)
x = Model(inputs= inputA, outputs=x)

y = Dense(64, activation='relu')(inputB)
y = Dense(32, activation='relu')(y)
y = Dense(8, activation='relu')(y)
y = Model(inputs=inputB, outputs=y)

result = concatenate([x.output, y.output])

z = Dense(2, activation='relu')(result)
z = Dense(1, activation='linear')(z)

model = Model(inputs=[x.input, y.input], outputs=z)

# %% [markdown]
# # RNN
